# %% [markdown]
# **Author:** Marcos Bujosa

# %% [markdown]
# $$
# \|\mathbf{x}\| = \sqrt{x_1^2 + x_2^2}, \qquad \|\mathbf{y}\| = \sqrt{y_1^2 + y_2^2 + y_3^2}.
# $$
#
# ![img](img/sesion03/LongitudVectorR2.png)
# ![img](img/sesion03/LongitudVectorR3.png)
#
# -   En $\mathbb{R}^3$: Pitágoras dos veces (primero el plano, luego la altura).
# -   En $\mathbb{R}^n$, por analogía: $\|\mathbf{x}\| = \sqrt{\sum_i x_i^2} = \sqrt{\mathbf{x}\cdot\mathbf{x}}$.
